# %% [markdown]
# <a href="https://colab.research.google.com/github/gopigit25/MachineLearning/blob/main/svm_exercise_digits.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.datasets import load_digits
digits = load_digits()

# %%
dir(digits)

# %%
df = pd.DataFrame(digits.data,digits.target)
df.head()

# %%
df['target']=digits.target
df.head()

# %%
X=df.drop(['target'],axis='columns')
Y=df.target
print(X.head())
print(Y.head())

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
from sklearn.svm import SVC
model=SVC()
model.fit(X_train,Y_train)
# Out:
# SVC()

# %%
len(X_train)
# Out:
# 1437

# %%
len(X_test)
# Out:
# 360

# %%
rbf_model = SVC(kernel='rbf')

# %%
rbf_model.fit(X_train, Y_train)
# Out:
# SVC()

# %%
rbf_model.score(X_test,Y_test)
# Out:
# 0.9861111111111112

# %% [markdown]
# #Using Linear kernel

# %%
linear_model = SVC(kernel='linear')
linear_model.fit(X_train,Y_train)
# Out:
# SVC(kernel='linear')

# %%
linear_model.score(X_test,Y_test)
# Out:
# 0.9777777777777777
